# %%
import re, sys, unicodedata
import csv
import gzip
import collections
import numpy as np
import urllib
import pyodbc
import pandas as pd
import sqlalchemy as sa
import numpy as np
import math
import xml.etree.ElementTree as ET
import pandas as pd

# %%
df = pd.read_excel(r'E:\Compound.xlsx')

# %%
df
# Out:
#            Id                                               Name Unnamed: 2
# 0      297728   (8R,9S,10R,13S,14S)-13-Methyl-1,2,4,7,8,9,10,...        Yes
# 1      329089                                   2-octylhydrazine        Yes
# 2      332103                                Calci glucoheptonat        Yes
# 3      332347                     Chất nhũ hóa lecithin đậu nành         No
# 4      332151                                   Collagen type I         Yes
# ...       ...                                                ...        ...
# 41148  326966                                    ω-6 fatty acids        Yes
# 41149  324030                                ω-aminobutyric acid        Yes
# 41150  329027                                ω-phenylacetic acid        Yes
# 41151  323340                              ω-Phenylbutanoic acid        Yes
# 41152  323339                               ω-phenylbutyric acid        Yes
#
# [41153 rows x 3 columns]

# %%
def dic_(value):
    x = value.replace(" ", "")
    dictionary = "A aB bC cD dE εeF fG gH hI iJ jK kL lM mN nO oP pQ qR rS sT tU uV vW wXä xY^ yZ~<> –z ±*%.α-−()0123456789,[]/\''{}:;,+-ωδψγ→β"
    y = dictionary.replace(" ", "")
    k = 0
    txt = ''
    z=0
    for i in range(len(x)):
        if txt.find(y[z]) == 0:
            k = k + 1
        for z in range(len(y)):
            txt = x[i]
            char = y[z]
            if txt.find(y[z]) == 0:
#                 print(x[i],i,txt.find(y[z]))
                break
#     print(k)
#     print(len(x))
    if (k+1) < len(x):
#         print("No")
        return 'No'
    else:
#         print("Yes")
        return 'Yes'

# %%
# message = "Arg34Lys26-(N-ε-(γ-Glu(N-α-hexadecanoyl)))-GLP-1[7-37]"
# print(message,(dic_(message)))
# Out:
# Arg34Lys26-(N-ε-(γ-Glu(N-α-hexadecanoyl)))-GLP-1[7-37] Yes

# %%
NAME = []
FLAG = []
for i in range(len(df['Name'])):
    message = df['Name'][i]
    NAME.append(message)
    FLAG.append(dic_(message))

# %%
df['FLAG'] = pd.DataFrame(FLAG)

# %%
df
# Out:
#            Id                                               Name Unnamed: 2  \
# 0      297728   (8R,9S,10R,13S,14S)-13-Methyl-1,2,4,7,8,9,10,...        Yes
# 1      329089                                   2-octylhydrazine        Yes
# 2      332103                                Calci glucoheptonat        Yes
# 3      332347                     Chất nhũ hóa lecithin đậu nành         No
# 4      332151                                   Collagen type I         Yes
# ...       ...                                                ...        ...
# 41148  326966                                    ω-6 fatty acids        Yes
# 41149  324030                                ω-aminobutyric acid        Yes
# 41150  329027                                ω-phenylacetic acid        Yes
# 41151  323340                              ω-Phenylbutanoic acid        Yes
# 41152  323339                               ω-phenylbutyric acid        Yes
#
#       FLAG
# 0      Yes
# 1      Yes
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 41148  Yes
# 41149  Yes
# 41150  Yes
# 41151  Yes
# 41152  Yes
#
# [41153 rows x 4 columns]

# %%
df.to_excel(r'E:\Compound_Re.xlsx')
