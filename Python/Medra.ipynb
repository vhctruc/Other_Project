# %%
import csv
import gzip
import collections
import pandas

# %%
columns_ = [
    'a',
    'b',
    'c',
    'd',
    'e',
    'f',
    'g'
]
meddra_all_label_se = pandas.read_table(r'D:\Medra\meddra_all_label_se.tsv', sep='\t', names=columns_)
meddra_all_label_se
# Out:
#                                              a             b             c  \
# 0                         EMA/WC500020092.html  CID100216416  CID000216416
# 1                         EMA/WC500020092.html  CID100216416  CID000216416
# 2                         EMA/WC500020092.html  CID100216416  CID000216416
# 3                         EMA/WC500020092.html  CID100216416  CID000216416
# 4                         EMA/WC500020092.html  CID100216416  CID000216416
# ...                                        ...           ...           ...
# 4753136  safety/2008_-_May_PI_-_Viread_PI.html  CID100119830  CID005481350
# 4753137  safety/2008_-_May_PI_-_Viread_PI.html  CID100119830  CID005481350
# 4753138  safety/2008_-_May_PI_-_Viread_PI.html  CID100119830  CID005481350
# 4753139  safety/2008_-_May_PI_-_Viread_PI.html  CID100119830  CID005481350
# 4753140  safety/2008_-_May_PI_-_Viread_PI.html  CID100119830  CID005481350
#
#                 d    e         f                      g
# 0        C0000737  LLT  C0000737         Abdominal pain
# 1        C0000737   PT  C0000737         Abdominal pain
# 2        C0000737   PT  C0687713  Gastrointestinal pain
# 3        C0002170  LLT  C0002170               Alopecia
# 4        C0002170   PT  C0002170               Alopecia
# ...           ...  ...       ...                    ...
# 4753136  C1565489  LLT  C1565489       Renal impairment
# 4753137  C1565489   PT  C0035078          Renal failure
# 4753138  C1565489   PT  C1565489       Renal impairment
# 4753139  C1608945  LLT  C1608945       Exfoliative rash
# 4753140  C1608945   PT  C1608945       Exfoliative rash
#
# [4753141 rows x 7 columns]

# %%
meddra_all_label_se['b'].nunique()
# Out:
# 1430

# %%
drug_name = pandas.read_table(r'D:\Medra\drug_names.tsv', sep='\t')
drug_name
# Out:
#       CID100000085                 carnitine
# 0     CID100000119        gamma-aminobutyric
# 1     CID100000137          5-aminolevulinic
# 2     CID100000143                leucovorin
# 3     CID100000146  5-methyltetrahydrofolate
# 4     CID100000158                      PGE2
# ...            ...                       ...
# 1424  CID156603655                pegaptanib
# 1425  CID156842239                       n-3
# 1426  CID170683024                         x
# 1427  CID170695640             colestyramine
# 1428  CID171306834                      K779
#
# [1429 rows x 2 columns]

# %%
drug_name.to_csv(r'D:\Medra\side-effects.csv')

# %%
def stitch_flat_to_pubchem(cid):
    assert cid.startswith('CID')
    return int(cid[3:]) - 1e8

def stitch_stereo_to_pubchem(cid):
    assert cid.startswith('CID')
    return int(cid[3:])

# %%
# Read DrugBank terms
url = 'https://raw.githubusercontent.com/dhimmel/SIDER4/master/data/side-effects.tsv'
drugbank_df = pandas.read_table(url)

# Pubchem to DrugBank mapping
# url = 'https://raw.githubusercontent.com/dhimmel/drugbank/3e87872db5fca5ac427ce27464ab945c0ceb4ec6/data/mapping/pubchem.tsv'
# drugbank_map_df = pandas.read_table(url)

# %%
drugbank_df
# Out:
#        drugbank_id                                      drugbank_name  \
# 0          DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 1          DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 2          DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 3          DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 4          DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# ...            ...                                                ...
# 153658     DB05738                         vapitadine dihydrochloride
# 153659     DB05738                         vapitadine dihydrochloride
# 153660     DB05738                         vapitadine dihydrochloride
# 153661     DB05738                         vapitadine dihydrochloride
# 153662     DB05738                         vapitadine dihydrochloride
#
#        umls_cui_from_meddra          side_effect_name
# 0                  C0000729          Abdominal cramps
# 1                  C0000737            Abdominal pain
# 2                  C0232492      Abdominal pain upper
# 3                  C0740651         Abdominal symptom
# 4                  C0877331  Abnormal clotting factor
# ...                     ...                       ...
# 153658             C0015230                      Rash
# 153659             C0234233                Tenderness
# 153660             C0041582                     Ulcer
# 153661             C0042487         Venous thrombosis
# 153662             C0042963                  Vomiting
#
# [153663 rows x 4 columns]

# %%
drugbank_df.to_csv(r'D:\Side_Effect.csv')

# %%
drugbank_map_df
# Out:
#        drugbank_id  pubchem_id
# 0          DB00014    11980055
# 1          DB00014    11981235
# 2          DB00014    11982741
# 3          DB00014    16052011
# 4          DB00014    23581804
# ...            ...         ...
# 204704     DB09028    74070157
# 204705     DB09028    74834862
# 204706     DB09028    77513518
# 204707     DB09028    87355970
# 204708     DB09028    87644641
#
# [204709 rows x 2 columns]

# %%
columns_ = [
    'drug_id',
    'drug_name'
]
drug_name = pandas.read_table(r'D:\Medra\drug_names.tsv', sep='\t', names=columns_)
drug_name
# Out:
#            drug_id                 drug_name
# 0     CID100000085                 carnitine
# 1     CID100000119        gamma-aminobutyric
# 2     CID100000137          5-aminolevulinic
# 3     CID100000143                leucovorin
# 4     CID100000146  5-methyltetrahydrofolate
# ...            ...                       ...
# 1425  CID156603655                pegaptanib
# 1426  CID156842239                       n-3
# 1427  CID170683024                         x
# 1428  CID170695640             colestyramine
# 1429  CID171306834                      K779
#
# [1430 rows x 2 columns]

# %%
columns = [
    'stitch_id_flat',
    'stitch_id_sterio',
    'umls_cui_from_label',
    'placebo',
    'frequency',
    'lower',
    'upper',
    'meddra_type',
    'umls_cui_from_meddra',
    'side_effect_name',
]
freq_df = pandas.read_table(r'D:\Medra\meddra_freq.tsv', sep='\t', names=columns)
freq_df
# Out:
#        stitch_id_flat stitch_id_sterio umls_cui_from_label placebo frequency  \
# 0        CID100000085     CID000010917            C0000737     NaN       21%
# 1        CID100000085     CID000010917            C0000737     NaN       21%
# 2        CID100000085     CID000010917            C0000737     NaN       21%
# 3        CID100000085     CID000010917            C0000737     NaN        5%
# 4        CID100000085     CID000010917            C0000737     NaN        5%
# ...               ...              ...                 ...     ...       ...
# 291627   CID171306834     CID071306834            C2830004     NaN        5%
# 291628   CID171306834     CID071306834            C2830004     NaN        5%
# 291629   CID171306834     CID071306834            C2830004     NaN        5%
# 291630   CID171306834     CID071306834            C2830004     NaN        9%
# 291631   CID171306834     CID071306834            C2830004     NaN        9%
#
#         lower  upper meddra_type umls_cui_from_meddra       side_effect_name
# 0        0.21   0.21         LLT             C0000737         Abdominal pain
# 1        0.21   0.21          PT             C0000737         Abdominal pain
# 2        0.21   0.21          PT             C0687713  Gastrointestinal pain
# 3        0.05   0.05         LLT             C0000737         Abdominal pain
# 4        0.05   0.05          PT             C0000737         Abdominal pain
# ...       ...    ...         ...                  ...                    ...
# 291627   0.00   0.05          PT             C2830004             Somnolence
# 291628   0.05   0.05         LLT             C2830004             Somnolence
# 291629   0.05   0.05          PT             C2830004             Somnolence
# 291630   0.09   0.09         LLT             C2830004             Somnolence
# 291631   0.09   0.09          PT             C2830004             Somnolence
#
# [291632 rows x 10 columns]

# %%
freq_df.to_csv(r'D:\Medra\TEST.csv')

# %%
columns = [
    'stitch_id_flat',
    'stitch_id_sterio',
    'umls_cui_from_label',
    'meddra_type',
    'umls_cui_from_meddra',
    'side_effect_name',
]
se_df = pandas.read_table(r'D:\Medra\meddra_all_se.tsv', sep='\t', names=columns)
# se_df['pubchem_id'] = se_df.stitch_id_sterio.map(stitch_stereo_to_pubchem)
# se_df = drugbank_map_df.merge(se_df)
se_df
# Out:
#        stitch_id_flat stitch_id_sterio umls_cui_from_label meddra_type  \
# 0        CID100000085     CID000010917            C0000729         LLT
# 1        CID100000085     CID000010917            C0000729          PT
# 2        CID100000085     CID000010917            C0000737         LLT
# 3        CID100000085     CID000010917            C0000737          PT
# 4        CID100000085     CID000010917            C0000737          PT
# ...               ...              ...                 ...         ...
# 309844   CID171306834     CID071306834            C3203358          PT
# 309845   CID171306834     CID071306834            C3665386         LLT
# 309846   CID171306834     CID071306834            C3665386          PT
# 309847   CID171306834     CID071306834            C3665596         LLT
# 309848   CID171306834     CID071306834            C3665596          PT
#
#        umls_cui_from_meddra       side_effect_name
# 0                  C0000729       Abdominal cramps
# 1                  C0000737         Abdominal pain
# 2                  C0000737         Abdominal pain
# 3                  C0687713  Gastrointestinal pain
# 4                  C0000737         Abdominal pain
# ...                     ...                    ...
# 309844             C1145670    Respiratory failure
# 309845             C3665386        Abnormal vision
# 309846             C3665347      Visual impairment
# 309847             C3665596                  Warts
# 309848             C0347390         Skin papilloma
#
# [309849 rows x 6 columns]

# %%
se_df.query("stitch_id_flat == 'CID100047725'")
# Out:
#     drugbank_id  pubchem_id stitch_id_flat stitch_id_sterio  \
# 0       DB00014       47725   CID100047725     CID000047725
# 1       DB00014       47725   CID100047725     CID000047725
# 2       DB00014       47725   CID100047725     CID000047725
# 3       DB00014       47725   CID100047725     CID000047725
# 4       DB00014       47725   CID100047725     CID000047725
# ..          ...         ...            ...              ...
# 449     DB00014       47725   CID100047725     CID000047725
# 450     DB00014       47725   CID100047725     CID000047725
# 451     DB00014       47725   CID100047725     CID000047725
# 452     DB00014       47725   CID100047725     CID000047725
# 453     DB00014       47725   CID100047725     CID000047725
#
#     umls_cui_from_label meddra_type umls_cui_from_meddra  \
# 0              C0000737         LLT             C0000737
# 1              C0000737          PT             C0687713
# 2              C0000737          PT             C0000737
# 3              C0002170         LLT             C0002170
# 4              C0002170          PT             C0002170
# ..                  ...         ...                  ...
# 449            C2979982          PT             C2979982
# 450            C2981158         LLT             C2981158
# 451            C2981158          PT             C2981158
# 452            C3495440         LLT             C3495440
# 453            C3495440          PT             C0025874
#
#           side_effect_name
# 0           Abdominal pain
# 1    Gastrointestinal pain
# 2           Abdominal pain
# 3                 Alopecia
# 4                 Alopecia
# ..                     ...
# 449    Vaginal haemorrhage
# 450         Loss of libido
# 451         Loss of libido
# 452  Bleeding breakthrough
# 453           Metrorrhagia
#
# [454 rows x 8 columns]

# %%
se_df = se_df[['drugbank_id', 'umls_cui_from_meddra', 'side_effect_name']]
se_df = se_df.dropna()
se_df = se_df.drop_duplicates(['drugbank_id', 'umls_cui_from_meddra'])
se_df = drugbank_df.merge(se_df)
se_df = se_df.sort_values(['drugbank_name', 'side_effect_name'])
len(se_df)
# Out:
# 153663

# %%
se_terms_df = se_df[['umls_cui_from_meddra', 'side_effect_name']].drop_duplicates()
assert se_terms_df.side_effect_name.duplicated().sum() == 0
se_terms_df = se_terms_df.sort_values('side_effect_name')
se_terms_df.to_csv(r'D:\Medra\side-effect-terms.tsv', sep='\t', index=False)

# %%
se_df.drugbank_id.nunique()
# Out:
# 1223

# %%
se_df.umls_cui_from_meddra.nunique()
# Out:
# 5734

# %%
# Save side effects
se_df.to_csv(r'D:\Medra\side-effects.tsv', sep='\t', index=False)

# %%
check_ = pandas.read_table(r'D:\Medra\side-effects.tsv', sep='\t', header= None)
check_
# Out:
#                   0                                                  1  \
# 0       drugbank_id                                      drugbank_name
# 1           DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 2           DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 3           DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 4           DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# ...             ...                                                ...
# 153659      DB05738                         vapitadine dihydrochloride
# 153660      DB05738                         vapitadine dihydrochloride
# 153661      DB05738                         vapitadine dihydrochloride
# 153662      DB05738                         vapitadine dihydrochloride
# 153663      DB05738                         vapitadine dihydrochloride
#
#                            2                     3
# 0       umls_cui_from_meddra      side_effect_name
# 1                   C0000729      Abdominal cramps
# 2                   C0000737        Abdominal pain
# 3                   C0232492  Abdominal pain upper
# 4                   C0740651     Abdominal symptom
# ...                      ...                   ...
# 153659              C0015230                  Rash
# 153660              C0234233            Tenderness
# 153661              C0041582                 Ulcer
# 153662              C0042487     Venous thrombosis
# 153663              C0042963              Vomiting
#
# [153664 rows x 4 columns]

# %%
check_.rename(columns={ 
    check_.columns[0]: 'drugbank_id', 
    check_.columns[1]: 'drugbank_name', 
    check_.columns[2]: 'umls_cui_from_meddra',
    check_.columns[3]: 'side_effect_name'}, inplace = True)

# %%
check_.to_csv(r'D:\Medra\side-effects.csv')

# %%
columns = [
    'stitch_id_flat',
    'umls_cui_from_label',
    'method',
    'concept_name',
    'meddra_type',
    'umls_cui_from_meddra',
    'meddra_name',
]
indication_df = pandas.read_table(r'D:\Medra\meddra_all_indications.tsv', names=columns)
indication_df['pubchem_id'] = indication_df.stitch_id_flat.map(stitch_flat_to_pubchem)

# %%
indication_df = drugbank_df.merge(drugbank_map_df.merge(indication_df))
indication_df = indication_df.query("meddra_type == 'PT'")
indication_df.head(2)
# Out:
#   drugbank_id drugbank_name  pubchem_id stitch_id_flat umls_cui_from_label  \
# 1     DB00014     Goserelin       47725   CID100047725            C0002871
# 3     DB00014     Goserelin       47725   CID100047725            C0006142
#
#            method                  concept_name meddra_type  \
# 1    text_mention                        Anemia          PT
# 3  NLP_indication  Malignant neoplasm of breast          PT
#
#   umls_cui_from_meddra    meddra_name
# 1             C0002871        Anaemia
# 3             C0006142  Breast cancer

# %%
# Multiple Sclerosis indications
indication_df.query("umls_cui_from_meddra == 'C0026769'").drugbank_name.tolist()
# Out:
# ['Baclofen',
#  'Betamethasone',
#  'Carbamazepine',
#  'Triamcinolone',
#  'Prednisone',
#  'Tizanidine',
#  'Hydrocortisone',
#  'Prednisolone',
#  'Methylprednisolone',
#  'Mitoxantrone',
#  'Dantrolene',
#  'Dexamethasone',
#  'FTY 720',
#  'Dalfampridine',
#  '(11alpha,14beta)-11,17,21-trihydroxypregn-4-ene-3,20-dione',
#  'Fingolimod']

# %%
df = pandas.DataFrame(indication_df)

# %%
df
# Out:
#       drugbank_id drugbank_name  pubchem_id stitch_id_flat  \
# 1         DB00014     Goserelin       47725   CID100047725
# 3         DB00014     Goserelin       47725   CID100047725
# 5         DB00014     Goserelin       47725   CID100047725
# 7         DB00014     Goserelin       47725   CID100047725
# 9         DB00014     Goserelin       47725   CID100047725
# ...           ...           ...         ...            ...
# 31448     DB09019    Bromhexine        2442   CID100002442
# 31450     DB09019    Bromhexine        2442   CID100002442
# 31452     DB09019    Bromhexine        2442   CID100002442
# 31454     DB09019    Bromhexine        2442   CID100002442
# 31456     DB09020     Bisacodyl        2391   CID100002391
#
#       umls_cui_from_label            method                  concept_name  \
# 1                C0002871      text_mention                        Anemia
# 3                C0006142    NLP_indication  Malignant neoplasm of breast
# 5                C0006826  NLP_precondition           Malignant Neoplasms
# 7                C0014175    NLP_indication                 Endometriosis
# 9                C0025323      text_mention                   Menorrhagia
# ...                   ...               ...                           ...
# 31448            C0009443      text_mention                   Common Cold
# 31450            C0009450      text_mention         Communicable Diseases
# 31452            C0010200    NLP_indication                      Coughing
# 31454            C0021400      text_mention                     Influenza
# 31456            C0009806    NLP_indication                  Constipation
#
#       meddra_type umls_cui_from_meddra         meddra_name
# 1              PT             C0002871             Anaemia
# 3              PT             C0006142       Breast cancer
# 5              PT             C0006826  Neoplasm malignant
# 7              PT             C0014175       Endometriosis
# 9              PT             C0025323         Menorrhagia
# ...           ...                  ...                 ...
# 31448          PT             C0035455            Rhinitis
# 31450          PT             C0009450           Infection
# 31452          PT             C0010200               Cough
# 31454          PT             C0021400           Influenza
# 31456          PT             C0009806        Constipation
#
# [16528 rows x 10 columns]

# %%
indication_df
# Out:
#       drugbank_id drugbank_name  pubchem_id stitch_id_flat  \
# 1         DB00014     Goserelin       47725   CID100047725
# 3         DB00014     Goserelin       47725   CID100047725
# 5         DB00014     Goserelin       47725   CID100047725
# 7         DB00014     Goserelin       47725   CID100047725
# 9         DB00014     Goserelin       47725   CID100047725
# ...           ...           ...         ...            ...
# 31448     DB09019    Bromhexine        2442   CID100002442
# 31450     DB09019    Bromhexine        2442   CID100002442
# 31452     DB09019    Bromhexine        2442   CID100002442
# 31454     DB09019    Bromhexine        2442   CID100002442
# 31456     DB09020     Bisacodyl        2391   CID100002391
#
#       umls_cui_from_label            method                  concept_name  \
# 1                C0002871      text_mention                        Anemia
# 3                C0006142    NLP_indication  Malignant neoplasm of breast
# 5                C0006826  NLP_precondition           Malignant Neoplasms
# 7                C0014175    NLP_indication                 Endometriosis
# 9                C0025323      text_mention                   Menorrhagia
# ...                   ...               ...                           ...
# 31448            C0009443      text_mention                   Common Cold
# 31450            C0009450      text_mention         Communicable Diseases
# 31452            C0010200    NLP_indication                      Coughing
# 31454            C0021400      text_mention                     Influenza
# 31456            C0009806    NLP_indication                  Constipation
#
#       meddra_type umls_cui_from_meddra         meddra_name
# 1              PT             C0002871             Anaemia
# 3              PT             C0006142       Breast cancer
# 5              PT             C0006826  Neoplasm malignant
# 7              PT             C0014175       Endometriosis
# 9              PT             C0025323         Menorrhagia
# ...           ...                  ...                 ...
# 31448          PT             C0035455            Rhinitis
# 31450          PT             C0009450           Infection
# 31452          PT             C0010200               Cough
# 31454          PT             C0021400           Influenza
# 31456          PT             C0009806        Constipation
#
# [16528 rows x 10 columns]

# %%
indication_df.to_csv(r'D:\Medra\indications.tsv', sep='\t', index=False)

# %%
check_1 = pandas.read_table(r'D:\Medra\indications.tsv', sep='\t', header= None)
check_1
# Out:
#                  0              1           2               3  \
# 0      drugbank_id  drugbank_name  pubchem_id  stitch_id_flat
# 1          DB00014      Goserelin       47725    CID100047725
# 2          DB00014      Goserelin       47725    CID100047725
# 3          DB00014      Goserelin       47725    CID100047725
# 4          DB00014      Goserelin       47725    CID100047725
# ...            ...            ...         ...             ...
# 16524      DB09019     Bromhexine        2442    CID100002442
# 16525      DB09019     Bromhexine        2442    CID100002442
# 16526      DB09019     Bromhexine        2442    CID100002442
# 16527      DB09019     Bromhexine        2442    CID100002442
# 16528      DB09020      Bisacodyl        2391    CID100002391
#
#                          4                 5                             6  \
# 0      umls_cui_from_label            method                  concept_name
# 1                 C0002871      text_mention                        Anemia
# 2                 C0006142    NLP_indication  Malignant neoplasm of breast
# 3                 C0006826  NLP_precondition           Malignant Neoplasms
# 4                 C0014175    NLP_indication                 Endometriosis
# ...                    ...               ...                           ...
# 16524             C0009443      text_mention                   Common Cold
# 16525             C0009450      text_mention         Communicable Diseases
# 16526             C0010200    NLP_indication                      Coughing
# 16527             C0021400      text_mention                     Influenza
# 16528             C0009806    NLP_indication                  Constipation
#
#                  7                     8                   9
# 0      meddra_type  umls_cui_from_meddra         meddra_name
# 1               PT              C0002871             Anaemia
# 2               PT              C0006142       Breast cancer
# 3               PT              C0006826  Neoplasm malignant
# 4               PT              C0014175       Endometriosis
# ...            ...                   ...                 ...
# 16524           PT              C0035455            Rhinitis
# 16525           PT              C0009450           Infection
# 16526           PT              C0010200               Cough
# 16527           PT              C0021400           Influenza
# 16528           PT              C0009806        Constipation
#
# [16529 rows x 10 columns]

# %%
check_1.rename(columns={ 
    check_1.columns[0]: 'drugbank_id', 
    check_1.columns[1]: 'drugbank_name', 
    check_1.columns[2]: 'pubchem_id',
    check_1.columns[3]: 'stitch_id_flat',
    check_1.columns[4]: 'umls_cui_from_label',
    check_1.columns[5]: 'method',
    check_1.columns[6]: 'concept_name',
    check_1.columns[7]: 'meddra_type',
    check_1.columns[8]: 'umls_cui_from_meddra',
    check_1.columns[9]: 'meddra_name'}, inplace = True)

# %%
check_1.to_csv(r'D:\Medra\indication_df.csv')
