# %%
import re
import pandas as pd
import io
from math import sin, cos, sqrt, atan2, radians
from math import radians, cos, sin, asin, sqrt
import matplotlib.pyplot as plt
from csv import reader
import sys
from bs4 import BeautifulSoup
from flatten_json import flatten
import json

# %%
df = pd.read_excel(r'D:\SE\ChongChiDinh_FLC.xlsx')
df
# Out:
#                  Name                                    ExtraProperties
# 0            Abacavir  {"accession_numbers":"{\"@attributes\":{\"prim...
# 1           Abatacept  {"accession_numbers":"{\"@attributes\":{\"prim...
# 2           Abciximab  {"accession_numbers":"{\"@attributes\":{\"prim...
# 3         Acamprosate  {"accession_numbers":"{\"@attributes\":{\"prim...
# 4            Acarbose  {"accession_numbers":"{\"@attributes\":{\"prim...
# ...               ...                                                ...
# 1371  Zoledronic acid  {"accession_numbers":"{\"@attributes\":{\"prim...
# 1372     Zolmitriptan  {"accession_numbers":"{\"@attributes\":{\"prim...
# 1373         Zolpidem  {"accession_numbers":"{\"@attributes\":{\"prim...
# 1374       Zonisamide  {"accession_numbers":"{\"@attributes\":{\"prim...
# 1375        Zopiclone  {"accession_numbers":"{\"@attributes\":{\"prim...
#
# [1376 rows x 2 columns]

# %%
sub_dict = {
    '&Agrave;' : 'À','&Otilde;' : 'Õ','&Ecirc;' : 'Ê','&ucirc;' : 'û','&Ocirc;' : 'Ô',
'&Aacute;' : 'Á','&Ouml;' : 'Ö','&Euml;' : 'Ë','&uuml;' : 'ü','&#149;' : '•',
'&Acirc;' : 'Â','&ograve;' : 'ò','&egrave;' : 'è','&#181;' : 'µ','&#153;' : '™',
'&Atilde;' : 'Ã','&oacute;' : 'ó','&eacute;' : 'é','&#215;' : '×','&copy;' : '©',
'&Auml;' : 'Ä','&ocirc;' : 'ô','&ecirc;' : 'ê','&Yacute;' : 'Ý','&reg;' : '®',
'&Aring;' : 'Å','&otilde;' : 'õ','&euml;' : 'ë','&#159;' : 'Ÿ','&#167;' : '§',
'&agrave;' : 'à','&ouml;' : 'ö','&#131;' : 'ƒ','&yacute;' : 'ý','&#182;' : '¶',
'&aacute;' : 'á','&Oslash;' : 'Ø','&Igrave;' : 'Ì','&yuml;' : 'ÿ',
'&acirc;' : 'â','&oslash;' : 'ø','&Iacute;' : 'Í','&#176;' : '°',
'&atilde;' : 'ã','&#140;' : 'Œ','&Icirc;' : 'Î','&#134;' : '†',
'&auml;' : 'ä','&#156;' : 'œ','&Iuml;' : 'Ï','&#135;' : '‡',
'&aring;' : 'å','&#138;' : 'Š','&igrave;' : 'ì','&lt;' : '<',
'&AElig;' : 'Æ','&#154;' : 'š','&iacute;' : 'í','&gt;' : '>',
'&aelig;' : 'æ','&Ugrave;' : 'Ù','&icirc;' : 'î','&#177;' : '±',
'&szlig;' : 'ß','&Uacute;' : 'Ú','&iuml;' : 'ï','&#171;' : '«',
'&Ccedil;' : 'Ç','&Ucirc;' : 'Û','&Ntilde;' : 'Ñ','&#187;' : '»',
'&ccedil;' : 'ç','&Uuml;' : 'Ü','&ntilde;' : 'ñ','&#191;' : '¿',
'&Egrave;' : 'È','&ugrave;' : 'ù','&Ograve;' : 'Ò','&#161;' : '¡',
'&Eacute;' : 'É','&uacute;' : 'ú','&Oacute;' : 'Ó','&#183;' : '·',
'&amp;' : '&','&lt;' : '<','&gt;' : '>','&nbsp;' : ' ','&le;' : '≤','&ge;' : '≥'
}

df['ExtraProperties'] = df['ExtraProperties'].replace(sub_dict,regex=True)
json_data = df['ExtraProperties']
df
# Out:
#                  Name                                    ExtraProperties
# 0            Abacavir  {"accession_numbers":"{\"@attributes\":{\"prim...
# 1           Abatacept  {"accession_numbers":"{\"@attributes\":{\"prim...
# 2           Abciximab  {"accession_numbers":"{\"@attributes\":{\"prim...
# 3         Acamprosate  {"accession_numbers":"{\"@attributes\":{\"prim...
# 4            Acarbose  {"accession_numbers":"{\"@attributes\":{\"prim...
# ...               ...                                                ...
# 1371  Zoledronic acid  {"accession_numbers":"{\"@attributes\":{\"prim...
# 1372     Zolmitriptan  {"accession_numbers":"{\"@attributes\":{\"prim...
# 1373         Zolpidem  {"accession_numbers":"{\"@attributes\":{\"prim...
# 1374       Zonisamide  {"accession_numbers":"{\"@attributes\":{\"prim...
# 1375        Zopiclone  {"accession_numbers":"{\"@attributes\":{\"prim...
#
# [1376 rows x 2 columns]

# %%
df_all = pd.DataFrame()
for i in range(len(json_data)):
    try:
        json_object = json.loads(json_data[i])
        json_formatted_str = json.dumps(json_object, indent=2)
        df = pd.json_normalize(json.loads(json_formatted_str))
        df_all = pd.concat([df, df_all])
    except:
        continue
df_all
# Out:
#                                     accession_numbers accession_number  \
# 0   {"@attributes":{"primary":"true"},"0":"DB01198...          DB01198
# 0   {"@attributes":{"primary":"true"},"0":"DB00909...          DB00909
# 0   {"@attributes":{"primary":"true"},"0":"DB00425...          DB00425
# 0   {"@attributes":{"primary":"true"},"0":"DB00315...          DB00315
# 0   {"@attributes":{"primary":"true"},"0":"DB00399...          DB00399
# ..                                                ...              ...
# 0   {"@attributes":{"primary":"true"},"0":"DB00284...          DB00284
# 0   {"@attributes":{"primary":"true"},"0":"DB00659...          DB00659
# 0   {"@attributes":{"primary":"true"},"0":"DB00054...          DB00054
# 0    {"@attributes":{"primary":"true"},"0":"DB01281"}          DB01281
# 0   {"@attributes":{"primary":"true"},"0":"DB01048...          DB01048
#
#                                             atc_codes  \
# 0   {"atc-code":{"@attributes":{"code":"N05CF01"},...
# 0   {"atc-code":[{"@attributes":{"code":"N03AX15"}...
# 0   {"atc-code":{"@attributes":{"code":"N05CF02"},...
# 0   {"atc-code":{"@attributes":{"code":"N02CC03"},...
# 0   {"atc-code":[{"@attributes":{"code":"M05BB08"}...
# ..                                                ...
# 0   {"atc-code":[{"@attributes":{"code":"A10BF01"}...
# 0   {"atc-code":{"@attributes":{"code":"N07BB03"},...
# 0   {"atc-code":{"@attributes":{"code":"B01AC13"},...
# 0   {"atc-code":{"@attributes":{"code":"L04AA24"},...
# 0   {"atc-code":[{"@attributes":{"code":"J05AR02"}...
#
#                                              synonyms  \
# 0   {"synonym":["(+-)-zopiclone","(\u00b1)-zopiclo...
# 0   {"synonym":["1,2-Benzisoxazole-3-methanesulfon...
# 0   {"synonym":["N,N,6-Trimethyl-2-(4-methylphenyl...
# 0   {"synonym":["(S)-4-({3-[2-(dimethylamino)ethyl...
# 0   {"synonym":["(1-hydroxy-2-(1H-imidazol-1-yl)et...
# ..                                                ...
# 0     {"synonym":["Acarbosa","Acarbose","Acarbosum"]}
# 0   {"synonym":["3-Acetamido-1-propanesulfonic aci...
# 0   {"synonym":["7E3","7E3 antibody","Abciximab (g...
# 0                 {"synonym":"Abatacept recombinant"}
# 0   {"synonym":["{(1S-cis)-4-[2-amino-6-(cycloprop...
#
#                                           description  \
# 0   Zopiclone is a novel hypnotic agent used in th...
# 0   Zonisamide is a sulfonamide anticonvulsant app...
# 0   Zolpidem is a prescription short-acting nonben...
# 0   Zolmitriptan is a synthetic tryptamine derivat...
# 0   Zoledronate (zoledronic acid, marketed by Nova...
# ..                                                ...
# 0   An inhibitor of alpha glucosidase that retards...
# 0   Acamprosate, also known by the brand name Camp...
# 0   Abciximab is a Fab fragment of the chimeric hu...
# 0   Abatacept is a soluble fusion protein, which l...
# 0   Abacavir (ABC) is a powerful nucleoside analog...
#
#                                        vi_description qua_lieu  \
# 0   <p dir="ltr"><strong>Tên thuốc gốc (Hoạt chất)...     None
# 0   <p dir="ltr"><strong>Tên thuốc gốc (Hoạt chất)...     None
# 0   <p dir="ltr"><strong>Tên thuốc gốc (Hoạt chất)...     None
# 0   <p><strong>Tên thuốc gốc (Hoạt chất)</strong><...     None
# 0   <p dir="ltr"><strong>Tên thuốc gốc (Hoạt chất)...     None
# ..                                                ...      ...
# 0   <p dir="ltr"><strong>Tên thuốc gốc (Hoạt chất)...     None
# 0   <p><strong>Tên thuốc gốc</strong></p>\r\n\r\n<...     None
# 0   <p><strong>Tên thuốc gốc (Hoạt chất)</strong><...     None
# 0   <p><strong>Tên thuốc gốc (Hoạt chất)</strong><...     None
# 0   <p><strong>Tên thuốc gốc (Hoạt chất)</strong><...     None
#
#                                                 luu_y  \
# 0   <h3 dir="ltr">Lưu ý chung</h3>\r\n\r\n<ul dir=...
# 0   <h3 dir="ltr">Lưu ý chung</h3>\r\n\r\n<p dir="...
# 0   <h3 dir="ltr">Lưu ý chung</h3>\r\n\r\n<p dir="...
# 0   <h3>Lưu ý chung</h3>\r\n\r\n<p><meta charset="...
# 0   <h3 dir="ltr">Lưu ý chung</h3>\r\n\r\n<p dir="...
# ..                                                ...
# 0   <h3 dir="ltr">Lưu ý chung</h3>\r\n\r\n<ul dir=...
# 0   <h3>Lưu ý chung</h3>\r\n\r\n<p>Do mối liên qua...
# 0   <h3>Lưu ý chung</h3>\r\n\r\n<p><strong>Giảm ti...
# 0   <h3 dir="ltr">Lưu ý chung</h3>\r\n\r\n<p dir="...
# 0   <h3 dir="ltr">Lưu ý chung</h3>\r\n\r\n<p dir="...
#
#                                          tac_dung_phu doi_tuong_su_dung  ...  \
# 0   <p dir="ltr"><meta charset="utf-8" />Khi sử dụ...              None  ...
# 0   <h3 dir="ltr">Thường gặp </h3>\r\n\r\n<p dir="...              None  ...
# 0   <h3 dir="ltr">Thường gặp </h3>\r\n\r\n<p dir="...              None  ...
# 0   <h3>Thường gặp </h3>\r\n\r\n<p><meta charset="...              None  ...
# 0   <h3 dir="ltr">Thường gặp </h3>\r\n\r\n<p dir="...              None  ...
# ..                                                ...               ...  ...
# 0   <h3 dir="ltr">Thường gặp </h3>\r\n\r\n<p dir="...              None  ...
# 0   <h3>Thường gặp</h3>\r\n\r\n<p><strong><a href=...              None  ...
# 0   <h3 style="margin:0in; margin-bottom:.0001pt; ...              None  ...
# 0   <h3 dir="ltr">Thường gặp </h3>\r\n\r\n<p dir="...              None  ...
# 0   <h3 dir="ltr">Thường gặp </h3>\r\n\r\n<p dir="...              None  ...
#
#                                      pharmacodynamics  \
# 0   Zopiclone is a nonbenzodiazepine hypnotic from...
# 0   Zonisamide is an antiseizure drug chemically c...
# 0   Zolpidem is a sedative or hypnotic agent with ...
# 0   Zolmitriptan is a selective agonist of seroton...
# 0   Zoledronate is a bisphosphonic acid which is a...
# ..                                                ...
# 0   Used to reduce blood gluose in patients with t...
# 0   Pharmacodynamic studies have shown that acampr...
# 0   Abciximab inhibits platelet aggregation by pre...
# 0   Abatacept is the first in a new class of drugs...
# 0   Abacavir is a nucleoside reverse transcriptase...
#
#                                   vi_pharmacodynamics  \
# 0   <p><strong>Zopiclone </strong>là thuốc an thần...
# 0   <p dir="ltr">Zonisamide là một dẫn xuất benzis...
# 0   <p>Zolpidem tartrat là một dẫn chất của imidaz...
# 0   <p>Zolmitriptan được chứng minh là chất chủ vậ...
# 0   <p dir="ltr">Zoledronic acid là một bisphospho...
# ..                                                ...
# 0   <p dir="ltr"><strong>Acarbose </strong>là một ...
# 0   <p>Acamprosate (Canxi Acetylhomotaurinate) có ...
# 0   <p><strong>Abciximab</strong> là một đoạn Fab ...
# 0   <p dir="ltr">Abatacept ức chế sự kích hoạt tế ...
# 0   <p>Abacavir là một thuốc thuộc nhóm nucleosid ...
#
#                                   mechanism_of_action  \
# 0   Zopiclone exerts its action by binding on the ...
# 0   Zonisamide binds to sodium channels and voltag...
# 0   Zolpidem modulates the alpha-subunit, known as...
# 0   Zolmitriptan binds with high affinity to human...
# 0   The action of zoledronate on bone tissue is ba...
# ..                                                ...
# 0   Acarbose reversibly bind to pancreatic alpha-a...
# 0   The mechanism of action of acamprosate in main...
# 0   Abciximab binds to the intact platelet GPIIb/I...
# 0   Abatacept is a selective costimulation modulat...
# 0   Abacavir is a carbocyclic synthetic nucleoside...
#
#                                vi_mechanism_of_action  \
# 0   <h3 dir="ltr">Hấp thu</h3>\r\n\r\n<p dir="ltr"...
# 0   <h3 dir="ltr">Hấp thu</h3>\r\n\r\n<p dir="ltr"...
# 0   <h3 dir="ltr">Hấp thu</h3>\r\n\r\n<p dir="ltr"...
# 0   <p><meta charset="utf-8" /></p>\r\n\r\n<h3 dir...
# 0   <h3 dir="ltr">Hấp thu</h3>\r\n\r\n<p dir="ltr"...
# ..                                                ...
# 0   <h3 dir="ltr">Hấp thu</h3>\r\n\r\n<p>Sau khi u...
# 0   <h3>Hấp thu</h3>\r\n\r\n<p>Sự hấp thu của Acam...
# 0   <p><strong>Abciximab</strong> liên kết với thụ...
# 0   <h3 dir="ltr">Hấp thu</h3>\r\n\r\n<p dir="ltr"...
# 0   <h3 dir="ltr">Hấp thu</h3>\r\n\r\n<p dir="ltr"...
#
#                                            metabolism  \
# 0   Extensively metabolized in the liver via decar...
# 0   Primarily hepatic through cytochrome P450 isoe...
# 0   Zolpidem is converted to inactive metabolites ...
# 0   Hepatic. There have been three metabolites ide...
# 0   Zoledronate does not inhibit human P450 enzyme...
# ..                                                ...
# 0   Acarbose is only metabolized within the gastro...
# 0            Acamprosate does not undergo metabolism.
# 0   Most likely removed by opsonization via the re...
# 0                                                None
# 0   Hepatic, by alcohol dehydrogenase and glucuron...
#
#                                         vi_metabolism  \
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# 0                                                None
# ..                                                ...
# 0                                                None
# 0                                                None
# 0   <h3>Hấp thu</h3>\r\n\r\n<p>Ức chế tối đa sự kế...
# 0                                                None
# 0                                                None
#
#                                  route_of_elimination  \
# 0                                                None
# 0   Zonisamide is excreted primarily in urine as p...
# 0   Zolpidem tartrate tablets are converted to ina...
# 0                                                None
# 0   In 64 patients with cancer and bone metastases...
# ..                                                ...
# 0   The fraction of acarbose that is absorbed as i...
# 0   Following oral administration of CAMPRAL®, the...
# 0                                                None
# 0                                    kidney and liver
# 0   Elimination of abacavir was quantified in a ma...
#
#                                              toxicity vi_toxicity  \
# 0   Rare individual instances of fatal outcomes fo...        None
# 0   Symptoms of overdose include diminished breath...        None
# 0   Oral (male rat) LD<sub>50</sub> = 695 mg/kg. S...        None
# 0                                                None        None
# 0   There is no experience of acute overdose. Two ...        None
# ..                                                ...         ...
# 0   Gastrointestinal symptoms are the most common ...        None
# 0   In all reported cases of acute overdosage with...        None
# 0                                                None        None
# 0   Most common adverse events (≥10%) are headache...        None
# 0   Some myocardial degeneration has been noticed ...        None
#
#                slug
# 0         zopiclone
# 0        zonisamide
# 0          zolpidem
# 0      zolmitriptan
# 0   zoledronic-acid
# ..              ...
# 0          acarbose
# 0       acamprosate
# 0         abciximab
# 0         abatacept
# 0          abacavir
#
# [1366 rows x 26 columns]

# %%
filter_result = df_all[['slug', 'chong_chi_dinh']].reset_index()
tac_dung_phu_clean = []
for i in range (len(filter_result['chong_chi_dinh'])):
    final_result = re.sub("\n|\r|\t", "@",filter_result['chong_chi_dinh'][i])
    tac_dung_phu_clean.append(final_result)
filter_result['tac_dung_phu_clean'] = pd.DataFrame(tac_dung_phu_clean)
filter_result
# Out:
#       index             slug  \
# 0         0        zopiclone
# 1         0       zonisamide
# 2         0         zolpidem
# 3         0     zolmitriptan
# 4         0  zoledronic-acid
# ...     ...              ...
# 1361      0         acarbose
# 1362      0      acamprosate
# 1363      0        abciximab
# 1364      0        abatacept
# 1365      0         abacavir
#
#                                          chong_chi_dinh  \
# 0     <p dir="ltr"><strong>Thuốc Zopiclone </strong>...
# 1     <p dir="ltr">Không dùng Zonisamide cho các trư...
# 2     <p dir="ltr">Không dùng thuốc Zolpidem cho các...
# 3     <p>Quá mẫn với hoạt chất zolmitriptan hoặc với...
# 4     <p dir="ltr">Không dùng thuốc Zoledronic acid ...
# ...                                                 ...
# 1361  <ul dir="ltr">\r\n\t<li>Chống chỉ định với các...
# 1362  <p><meta charset="utf-8" />Acamprosate chống c...
# 1363  <ul>\r\n\t<li>Chảy máu tạng, chảy máu nội tạng...
# 1364  <p dir="ltr">Quá mẫn với hoạt chất hoặc với bấ...
# 1365  <p dir="ltr">Dị ứng với abacavir hoặc với một ...
#
#                                      tac_dung_phu_clean
# 0     <p dir="ltr"><strong>Thuốc Zopiclone </strong>...
# 1     <p dir="ltr">Không dùng Zonisamide cho các trư...
# 2     <p dir="ltr">Không dùng thuốc Zolpidem cho các...
# 3     <p>Quá mẫn với hoạt chất zolmitriptan hoặc với...
# 4     <p dir="ltr">Không dùng thuốc Zoledronic acid ...
# ...                                                 ...
# 1361  <ul dir="ltr">@@@<li>Chống chỉ định với các tr...
# 1362  <p><meta charset="utf-8" />Acamprosate chống c...
# 1363  <ul>@@@<li>Chảy máu tạng, chảy máu nội tạng đa...
# 1364  <p dir="ltr">Quá mẫn với hoạt chất hoặc với bấ...
# 1365  <p dir="ltr">Dị ứng với abacavir hoặc với một ...
#
# [1366 rows x 4 columns]

# %%
a = '@' + filter_result['tac_dung_phu_clean']
a
# Out:
# 0       @Khi sử dụng thuốc Zopiclone, bạn có thể gặp c...
# 1       @Thường gặp ;@@@@Chán ăn, kích động, cáu gắt, ...
# 2       @Thường gặp ;@@@@Buồn ngủ, ngủ lịm, nhức đầu, ...
# 3       @Thường gặp ;@@@@@@@@Suy nhược cơ thể, đau đầu...
# 4       @Thường gặp ;@@@@Giảm phosphate máu, thiếu máu...
#                               ...
# 1362    @Thường gặp ;@@@@Tiêu hóa: Đầy bụng, phân nát,...
# 1363    @Thường gặp@@@@Tiêu chảy, ngứa, ban dát sẩn, l...
# 1364    @Thường gặp@@@@Chảy máu, đau lưng, hạ huyết áp...
# 1365    @Thường gặp ;@@@@Nhiễm trùng đường hô hấp trên...
# 1366    @Thường gặp ;@@@@Nôn, buồn nôn, nhức đầu, chán...
# Name: tac_dung_phu_clean, Length: 1367, dtype: object

# %%
filter_result.to_excel(r'D:\TEST123.xlsx',sheet_name = 'TEST')
