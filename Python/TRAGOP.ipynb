# %%
import os
import pandas as pd
import numpy as np

from datetime import datetime
import json
import ast

from numpy import reshape

import matplotlib.pyplot as plt

from sklearn.cluster import KMeans, DBSCAN
from sklearn import metrics
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

from scipy.stats import poisson, expon, nbinom

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from io import StringIO

# %%
df1 = pd.read_csv(r'D:\province_district_list.xlxs')

# %%
# df1 = pd.read_csv(r'D:\TRAGOP\FILES\2019\201902.csv', sep='\t', encoding = 'utf-16', on_bad_lines='warn')
# Out:
# b'Skipping line 3172: expected 41 fields, saw 42\n'
# b'Skipping line 36189: expected 41 fields, saw 42\nSkipping line 40534: expected 41 fields, saw 42\n'
# b'Skipping line 56190: expected 41 fields, saw 42\nSkipping line 56515: expected 41 fields, saw 42\n'
# b'Skipping line 73434: expected 41 fields, saw 42\nSkipping line 80044: expected 41 fields, saw 42\n'
# b'Skipping line 98176: expected 41 fields, saw 42\n'
# b'Skipping line 111875: expected 41 fields, saw 42\nSkipping line 113237: expected 41 fields, saw 42\n'
# b'Skipping line 127201: expected 41 fields, saw 42\n'
# b'Skipping line 138751: expected 41 fields, saw 42\nSkipping line 140825: expected 41 fields, saw 42\n'

# %%
# df1 = pd.read_csv(r'D:\TRAGOP\FILES\2019\201902.csv', on_bad_lines=lambda x: x[:-1], engine='python',sep='\t', encoding = 'utf-16')

# %%
df1 = df1.sort_values(by=['Số Đơn Hàng FULL'],ascending=True)

# %%
df1
# Out:
#        Số Hóa Đơn  Số Đơn Hàng Mã Khách Hàng         Tên Khách Hàng  \
# 0        '0353535     20090643      '7581578       NGUYỄN VĂN THẮNG
# 1        '0358172     20258308     '10338267          Giắn chăn vằn
# 2        '0001791     20310532      '1290772      Giang Trung Chánh
# 3        '0162522     20095661      '1235904         NGUYỄN ĐỨC TÂM
# 4        '0018957     20188409     '10308508              VÕ THỊ LÝ
# ...           ...          ...           ...                    ...
# 141361   '0289164     20254481      '3783771       TRIỆU QUANG DŨNG
# 141362   '0244812     20332436      '5119016  GIANG THỊ LAN PHƯƠNG
# 141363   '0107049     20339845      '3076023    TRẦN THỊ THANH BÌNH
# 141364   '0098690     20078781      '8837568                  Cô lệ
# 141365   '0089651     20067089      '5088878      ĐỖ HUỲNH THANH LÝ
#
#                  CMND Số Điện Thoại Mã Số Thuế Ngày Tạo Đơn Hàng  \
# 0          '271231591    XXXXXXXXXX        NaN       '10/02/2019
# ...

# %%
df2 = df1.loc[df1['Số Đơn Hàng FULL'].isnull()]

# %%
df3 = df1.dropna(subset=['Số Đơn Hàng FULL'])

# %%
df3
# Out:
#        Số Hóa Đơn  Số Đơn Hàng Mã Khách Hàng         Tên Khách Hàng  \
# 0        '0353535     20090643      '7581578       NGUYỄN VĂN THẮNG
# 1        '0358172     20258308     '10338267          Giắn chăn vằn
# 2        '0001791     20310532      '1290772      Giang Trung Chánh
# 3        '0162522     20095661      '1235904         NGUYỄN ĐỨC TÂM
# 4        '0018957     20188409     '10308508              VÕ THỊ LÝ
# ...           ...          ...           ...                    ...
# 141361   '0289164     20254481      '3783771       TRIỆU QUANG DŨNG
# 141362   '0244812     20332436      '5119016  GIANG THỊ LAN PHƯƠNG
# 141363   '0107049     20339845      '3076023    TRẦN THỊ THANH BÌNH
# 141364   '0098690     20078781      '8837568                  Cô lệ
# 141365   '0089651     20067089      '5088878      ĐỖ HUỲNH THANH LÝ
#
#                  CMND Số Điện Thoại Mã Số Thuế Ngày Tạo Đơn Hàng  \
# 0          '271231591    XXXXXXXXXX        NaN       '10/02/2019
# ...

# %%
df2
# Out:
#        Số Hóa Đơn  Số Đơn Hàng Mã Khách Hàng    Tên Khách Hàng        CMND  \
# 3170     '1239925     20328654     '10364599  LONG THỊ TỪ NIỆM  '261100634
# 36187    '1239925     20328654     '10364599  LONG THỊ TỪ NIỆM  '261100634
# 40532    '1258437     20436146     '10406521   Nguyễn Thị Hoài  '364175674
# 56188    '1258437     20436146     '10406521   Nguyễn Thị Hoài  '364175674
# 56513    '1251451     20397470     '10391709     Trần Đăng Đạo  '250843296
# 73432    '1258437     20436146     '10406521   Nguyễn Thị Hoài  '364175674
# 80042    '1258437     20436146     '10406521   Nguyễn Thị Hoài  '364175674
# 98174    '1251451     20397470     '10391709     Trần Đăng Đạo  '250843296
# 111873   '1239925     20328654     '10364599  LONG THỊ TỪ NIỆM  '261100634
# 113235   '1239925     20328654     '10364599  LONG THỊ TỪ NIỆM  '261100634
# 127199   '1251451     20397470     '10391709     Trần Đăng Đạo  '250843296
# ...

# %%
df2.replace({'H':{'X':np.nan}}).apply(lambda x: sorted(x, key=pd.isnull),1).fillna('')
# Out:
# 3170      ['1239925, 20328654, '10364599, LONG THỊ TỪ NI...
# 36187     ['1239925, 20328654, '10364599, LONG THỊ TỪ NI...
# 40532     ['1258437, 20436146, '10406521, Nguyễn Thị Hoà...
# 56188     ['1258437, 20436146, '10406521, Nguyễn Thị Hoà...
# 56513     ['1251451, 20397470, '10391709, Trần Đăng Đạo,...
# 73432     ['1258437, 20436146, '10406521, Nguyễn Thị Hoà...
# 80042     ['1258437, 20436146, '10406521, Nguyễn Thị Hoà...
# 98174     ['1251451, 20397470, '10391709, Trần Đăng Đạo,...
# 111873    ['1239925, 20328654, '10364599, LONG THỊ TỪ NI...
# 113235    ['1239925, 20328654, '10364599, LONG THỊ TỪ NI...
# 127199    ['1251451, 20397470, '10391709, Trần Đăng Đạo,...
# 138749    ['1258437, 20436146, '10406521, Nguyễn Thị Hoà...
# 140823    ['1258437, 20436146, '10406521, Nguyễn Thị Hoà...
# dtype: object

# %%
df2
# Out:
#        Số Hóa Đơn  Số Đơn Hàng Mã Khách Hàng    Tên Khách Hàng        CMND  \
# 3170     '1239925     20328654     '10364599  LONG THỊ TỪ NIỆM  '261100634
# 36187    '1239925     20328654     '10364599  LONG THỊ TỪ NIỆM  '261100634
# 40532    '1258437     20436146     '10406521   Nguyễn Thị Hoài  '364175674
# 56188    '1258437     20436146     '10406521   Nguyễn Thị Hoài  '364175674
# 56513    '1251451     20397470     '10391709     Trần Đăng Đạo  '250843296
# 73432    '1258437     20436146     '10406521   Nguyễn Thị Hoài  '364175674
# 80042    '1258437     20436146     '10406521   Nguyễn Thị Hoài  '364175674
# 98174    '1251451     20397470     '10391709     Trần Đăng Đạo  '250843296
# 111873   '1239925     20328654     '10364599  LONG THỊ TỪ NIỆM  '261100634
# 113235   '1239925     20328654     '10364599  LONG THỊ TỪ NIỆM  '261100634
# 127199   '1251451     20397470     '10391709     Trần Đăng Đạo  '250843296
# ...
